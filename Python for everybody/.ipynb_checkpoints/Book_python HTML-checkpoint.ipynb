# %% [markdown]
# ___NETWORK PROGRAMMING:___ Internet sources of information

# %% [markdown]
# __Hypertext transfer protocol(HTTP):__ https://www.w3.org/Protocols/rfc2616/rfc2616.txt

# %%
# Manual way to retrive a text from a website -- for images look page 152 
import socket
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM) #connecting as a web browser socket -- Send and recieve data
mysock.connect(('data.pr4e.org', 80))  # website and port we will connect (http:80,https:443,ftp:21,email:25,etc) 
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode() # as web browser sending through http, we must use GET followed by a blankline \r\n\r\n
mysock.send(cmd)
while True:
    data = mysock.recv(512) # a loop that recieves data in chunks of 512 characters from the socket
    if len(data) < 1:       # the loop continue retriving until there are 0 characters left to read
        break
    print(data.decode(),end='') # switch the end default parameter from\n to ''
mysock.close()
# THERE IS A EASY WAY USING URLIB !!
# Out:
# HTTP/1.1 200 OK
# Date: Thu, 10 Jun 2021 18:35:32 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
# retriving a text file from the web
import urllib.request # lets do the same previous process but using urllib
fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')# fhand has the info as though it were a file
for line in fhand: # just make sure to decode !!
    print(line.decode().strip()) # you need to decode beacuse the info comes in bytes ! (you'll see an object not a string)
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
# retriving a non-text file (binary) -- images,video,etc...
import urllib.request, urllib.parse, urllib.error
img = urllib.request.urlopen('http://data.pr4e.org/cover3.jpg').read() #saving the image data in a variable--you need to read it
fhand = open('cover3.jpg', 'wb') #  wb means open with writing in a binary mode(b), as the file doesn't exist generates a new one in the path...
fhand.write(img) # we are puting the binary data in the new document
fhand.close()
# but if the file is larger than your CPu memory the program will crash. So do it in chunks

# %%
import urllib.request, urllib.parse, urllib.error
img = urllib.request.urlopen('http://data.pr4e.org/cover3.jpg') # saving the data in a variable
fhand = open('cover3.jpg', 'wb') #opening a new file in writing and binary mood
size = 0 
while True:                   # loop for saving in chunks
    info = img.read(100000)   # read the data (in img) by chunks of 100.000 characters
    if len(info) < 1: break   # exhaust the data in img 
    size = size + len(info)   # count the amount of charchters -- optional
    fhand.write(info)         # put each chunk in the new bianry file
print(size, 'characters copied.')
fhand.close()
#obtain the same result as in the previous code but whithout a crashing risk !!!!
# Out:
# 230210 characters copied.

# %% [markdown]
# __Parsing and Scraping the web__ (HTML)

# %%
# retriving urls within a url -- using regular expressions
import urllib.request, urllib.parse, urllib.error
import re
import ssl

ctx = ssl.create_default_context() ## SSl certificate errors allows to access websites that extrictly enforce HTTPS.
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter web site url')
html = urllib.request.urlopen(url,context = ctx).read() # save and read the dta in a variable
links = re.findall(b'href="(http[s]?://.*?)"', html) # b' beacus the data is coded. retrive all that contains “href="http://” 
                          # or “href="http://” ([s]?->followed by 0 or 1 s). Then, zero or more characters up to " (.*") in the
for link in links:        # non-greedy  mood (?). stops at the first final" t finds.
    print(link.decode()) # remember to decode the data if want to see it as a string!!!
# this only works when the HTML in the web is well formatted.Otherwise you'll skip important information.
# Its better to use a parsing library: e.g., beautifulsoup
# Out:
# Enter web site url https://docs.python.org/3/library/functions.html#open
# https://docs.python.org/3/library/functions.html
# https://www.python.org/
# https://www.python.org/dev/peps/pep-0475
# https://rhettinger.wordpress.com/2011/05/26/super-considered-super/
# https://www.python.org/dev/peps/pep-0302
# https://www.python.org/dev/peps/pep-0328
# https://github.com/python/cpython/blob/3.9/Doc/library/functions.rst
# https://www.python.org/
# https://www.python.org/psf/donations/
# https://docs.python.org/3/bugs.html
# https://www.sphinx-doc.org/

# %%
#Using a praser library -- BEAUTIFULSOUP
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

ctx = ssl.create_default_context()  # SSL Certificate errors
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')  ## ask for a website url
html = urllib.request.urlopen(url, context=ctx).read() #store the data in a variable
soup = BeautifulSoup(html, 'html.parser')  # use bs4 to parse the data in the html mode and save it in a variable

tags = soup('a')  # Retrieve all of the anchor tags of html (<a..>...</a>)
for tag in tags:
    print("Tag:", tag) # the whole tag in the anhor "a"
    print("URL:", tag.get('href', None)) # get herf and if there isn't herf, retrives None.
    print("Body of tag:", tag.contents[0]) # contents retrives a list of one element. that's why [0]
    print("Attrs:", tag.attrs) # returns a dict info of the anchor.
    
# There is alot of usages that beautiful soup can do regarding to parse HTML. Read the documentation !!!
# Out:
# Enter -  http://www.dr-chuck.com/page1.htm
# Tag: <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>
# URL: http://www.dr-chuck.com/page2.htm
# Body of tag:
# Second Page
# Attrs: {'href': 'http://www.dr-chuck.com/page2.htm'}

# %%
#Exercise 1
import socket
import re
web_ = input("enter the url")
protocol_list = re.findall("(http.*):",web_)
protocol = protocol_list[0].lower()
port = 0
if protocol == "http": port = 80
else: port = 443
body_list = re.findall("//(.+?)/",web_)
body = body_list[0]
    
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM) 
mysock.connect((body, port)) 
cmd = 'GET '+str(web_)+' '+protocol.upper()+'/1.0\r\n\r\n'
cmd = cmd.encode()
mysock.send(cmd)
while True:
    data = mysock.recv(512) 
    if len(data) < 1:       
        break
    print(data.decode(),end='') #
mysock.close()
# Out:
# enter the url https://www.w3.org/Protocols/rfc2616/rfc2616.txt

# %%
#exercise 3
import urllib.request, urllib.parse, urllib.error
import re
import ssl
from bs4 import BeautifulSoup

web_ = input("enter the url")

ctx = ssl.create_default_context()  # SSL Certificate errors
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

info = urllib.request.urlopen(web_, context=ctx)
#html = BeautifulSoup(info, 'html.parser')
counter = 0
list_3000 = list()
for line in info:
    line = line.decode()
    for each in line:
        if len(each) > 0 and counter < 3000:
            counter += 1
            list_3000.append(each)
        
print ('The number of characters is: %d'%counter,"\n"+"".join(list_3000))
# Out:
# enter the url https://en.wikipedia.org/wiki/Nero
# The number of characters is: 3000
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Nero - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"8ef4c6ad-331f-454a-a03a-3076925f2453","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Nero","wgTitle":"Nero","wgCurRevisionId":1027854148,"wgRevisionId":1027854148,"wgArticleId":21632,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template other archives","Webarchive template wayback links","Webarchive template webcite links","Webarchive template archiveis links","Articles with short description","Short description is different from Wikidata","Wikipedia indefinitely semi-protected pages","Use dmy dates from April 2020",
# "All articles with unsourced statements","Articles with unsourced statements from June 2009","Articles with unsourced statements from September 2017","Articles needing additional references from June 2020","All articles needing additional references","Articles with French-language sources (fr)","Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference","Commons category link is on Wikidata","Wikipedia articles with BIBSYS identifiers","Wikipedia articles with BNC identifiers","Wikipedia articles with BNE identifiers","Wikipedia articles with BNF identifiers","Wikipedia articles with CANTIC identifiers","Wikipedia articles with FAST identifiers","Wikipedia articles with GND identifiers","Wikipedia articles with ISNI identifiers","Wikipedia articles with LCCN identifiers","Wikipedia articles with LNB identifiers","Wikipedia articles with MusicBrainz identifiers","Wikipedia articles with NDL identifiers",
# "Wikipedia articles with NKC identifiers","Wikipedia articles with NLI identifiers","Wikipedia articles with NLP identifiers","Wikipedia articles with NTA identifiers","Wikipedia articles with PLWABN identifiers","Wikipedia articles with SELIBR identifiers","Wikipedia articles with SNAC-ID identifiers","Wikipedia articles with SUDOC identifiers","Wikipedia articles with ULAN identifiers","Wikipedia articles with VcBA identifiers","Wikipedia articles with VIAF identifiers","Wikipedia articles with WORLDCATID identifiers","Wikipedia articles with multiple identifiers","Julio-Claudian dynasty","Nero","37 births","68 deaths","1st-century Roman emperors","Ancient LGBT people","Ancient Roman adoptees","Ancient Romans who committed suicide","LGBT royalty","Children of Claudius","Claudii Nerones","Domitii Ahenobarbi","Forced suicides","Italian rapists","LGBT heads of state","LGBT people from Italy","Matricides","Peop

# %%
# exercise 4
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

ctx = ssl.create_default_context() 
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ') 
html = urllib.request.urlopen(url, context=ctx).read() 
soup = BeautifulSoup(html, 'html.parser') 

tags = soup.find_all('p')  
counter = 0
for tag in tags:
    counter += 1 
print("Number of paragraphs: %d"%counter)
# Out:
# Enter -  https://en.wikipedia.org/wiki/Nero
# Number of paragraphs: 94

# %%
http://data.pr4e.org/romeo.txt
# Out:
#  dsf

# %% [markdown]
# __Data Analytics__

# %%
#Web search -- withou log in
import requests
import json
srch = input('search: ')
srch = srch.replace(' ','%20')
url = 'https://api.stlouisfed.org/fred/series/search?api_key=fa0335cf11bfeae9385db5fe1b238a3a&file_type=json&search_text=%s'%srch
url1 = 'https://en.wikipedia.org/wiki/Main_Page'

response = requests.get(url).json()#put .json()-no estatus code is a dict when json- at the end if the answer is in that format
 # the data is in HTML format...needs to be tranformed into string (utf-8)-> remove the bi code (b')
#print(response.status_code) # if is 200, it is a succesful connection
for i in response['seriess']:
        print(i['title'])

#str_ = response.content.decode('utf-8')
#str_
#indx = str_.find("Did you know")
#print(indx)



#FRED api key = fa0335cf11bfeae9385db5fe1b238a3a
# Out:
# search:  500
# S&P 500
# CBOE S&P 500 3-Month Volatility Index
# Nonfarm Private Large Payroll Employment (500 - 999)
# Real Median Household Income in the United States
# Nonfarm Private Service - Providing Large Payroll Employment (500 - 999)
# Nonfarm Private Goods - Producing Large Payroll Employment (500 - 999)
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# New Houses Sold by Sales Price in the United States, Between $500,000 and $749,999
# Median Household Income in the United States
# Volume of Currency in Circulation: $500 to $10,000
# Value of Currency in Circulation: $500 to $10,000
# Electricity Per 500 KWH in U.S. City Average
# New Houses Sold by Sales Price Between $500,000 and Over in Midwest Census Region
# New Houses Sold by Sales Price Between $500,000 and Over in South Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in Northeast Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in West Census Region
# Electricity Per 500 KWH in San Diego-Carlsbad, CA (CBSA)
# Electricity Per 500 KWH in Pittsburgh, PA (CBSA)
# Electricity Per 500 KWH in Atlanta-Sandy Springs-Roswell, GA (CBSA)
# Electricity Per 500 KWH in Boston-Cambridge-Newton, MA-NH (CBSA)
# Electricity Per 500 KWH in Los Angeles-Riverside-Orange County, CA (CBSA)
# Electricity Per 500 KWH in Chicago-Naperville-Elgin, IL-IN-WI (CBSA)
# Electricity Per 500 KWH in Kansas City, MO-KS (CBSA)
# Electricity Per 500 KWH in New York-Newark-Jersey City, NY-NJ-PA (CBSA)
# Electricity Per 500 KWH in Seattle-Tacoma-Bellevue, WA (CBSA)
# Electricity Per 500 KWH in Houston-The Woodlands-Sugar Land, TX (CBSA)
# New Houses Sold by Sales Price Between $500,000 and Over in the South Census Region
# New Houses Sold by Sales Price Between $500,000 and Over in the South Census Region
# New Houses Sold by Sales Price Between $500,000 and Over in the South Census Region
# Electricity Per 500 KWH in San Francisco-Oakland-Hayward, CA (CBSA)
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the West Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the West Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the West Census Region
# Electricity Per 500 KWH in Dallas-Fort Worth-Arlington, TX (CBSA)
# Electricity Per 500 KWH in Midwest Urban
# New Houses Sold by Sales Price Between $500,000 and Over in the Midwest Census Region
# New Houses Sold by Sales Price Between $500,000 and Over in the Midwest Census Region
# New Houses Sold by Sales Price Between $500,000 and Over in the Midwest Census Region
# Electricity Per 500 KWH in Minneapolis-St.Paul-Bloomington, MN-WI (CBSA)
# Electricity Per 500 KWH in Washington, DC-MD-VA (CBSA)
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the Northeast Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the Northeast Census Region
# New Houses Sold by Sales Price Between $500,000 and $749,999 in the Northeast Census Region
# Electricity Per 500 KWH in South - Size Class B
# Electricity Per 500 KWH in Detroit-Warren-Dearborn, MI (CBSA)
# Cash in Vault for All Member Banks in Cities with 500,000 or More Residents
# Electricity Per 500 KWH in Miami-Fort Lauderdale-West Palm Beach, FL (CBSA)
# Electricity Per 500 KWH in South - Size Class C
# Electricity Per 500 KWH in Buffalo-Niagara Falls, NY (CBSA)
# Diffusion Index, New Capital Appropriations, 500 Manufacturing Companies, Four Quarter Span for United States
# Electricity Per 500 KWH in Cleveland-Akron, OH (CBSA)
# Electricity Per 500 KWH in Cincinnati-Hamilton, OH-KY-IN (CBSA)
# Electricity Per 500 KWH in West - Size Class A
# Electricity Per 500 KWH in City - Size Class B
# Electricity Per 500 KWH in Urban Alaska (CBSA)
# Electricity Per 500 KWH in St. Louis, MO-IL (CBSA)
# Electricity Per 500 KWH in Milwaukee-Racine, WI (CBSA)
# Electricity Per 500 KWH in Los Angeles-Long Beach-Anaheim, CA (CBSA)
# Electricity Per 500 KWH in Washington-Baltimore, DC-MD-VA-WV (CBSA)
# Electricity Per 500 KWH in Midwest - Size Class A
# Electricity Per 500 KWH in North Central - Size Class C
# Loans in All Member Banks in Cities with 500,000 or More Residents
# Electricity Per 500 KWH in West Urban
# Electricity Per 500 KWH in South Urban
# Electricity Per 500 KWH in Size Class A
# Electricity Per 500 KWH in Size Class B/C
# Electricity Per 500 KWH in Northeast Urban
# Electricity Per 500 KWH in Scranton, PA (CBSA)
# Electricity Per 500 KWH in West - Size Class B
# Electricity Per 500 KWH in City - Size Class C
# Electricity Per 500 KWH in West - Size Class C
# Electricity Per 500 KWH in West - Size Class D
# Electricity Per 500 KWH in Baltimore, MD (CBSA)
# Electricity Per 500 KWH in South - Size Class D
# Electricity Per 500 KWH in South - Size Class A
# Electricity Per 500 KWH in West - Size Class B/C
# Electricity Per 500 KWH in Midwest - Size Class D
# Electricity Per 500 KWH in South - Size Class B/C
# Electricity Per 500 KWH in Northeast - Size Class C
# Electricity Per 500 KWH in Midwest - Size Class B/C
# Electricity Per 500 KWH in Northeast - Size Class B/C
# Electricity Per 500 KWH in Denver-Aurora-Lakewood, CO (CBSA)
# Electricity Per 500 KWH in Baltimore-Columbia-Towson, MD (CBSA)
# Electricity Per 500 KWH in Washington-Arlington-Alexandria, DC-VA-MD-WV (CBSA)
# Electricity Per 500 KWH in Northeast - Size Class B
# Electricity Per 500 KWH in Northeast - Size Class D
# Electricity Per 500 KWH in Northeast - Size Class A
# Electricity Per 500 KWH in Urban Hawaii (CBSA)
# Electricity Per 500 KWH in Portland-Salem, OR-WA (CBSA)
# Electricity Per 500 KWH in North Central - Size Class B
# Electricity Per 500 KWH in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD (CBSA)
# Electricity Per 500 KWH in City - Size Class D
# Time Deposits in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Reserves with Federal Reserve Banks for All Member Banks in Cities with 500,000 or Fewer Residents
# Loans in All Member Banks in Cities with 500,000 or Fewer Residents
# Investments in All Member Banks in Cities with 500,000 or Fewer Residents
# Other Securities in All Member Banks in Cities with 500,000 or More Residents
# Other Securities in All Member Banks in Cities with 500,000 or Fewer Residents
# Loans in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Interbank Deposits in All Member Banks in Cities with 500,000 or Fewer Residents
# Deposits in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Deposits in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Loans and Investments in All Member Banks in Cities with 500,000 or More Residents
# Loans and Investments in All Member Banks in Cities with 500,000 or Fewer Residents
# Time Deposits in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Cash in Vault for All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Demand Deposits in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Demand Deposits in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Interbank Deposits in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Interbank Deposits in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# United States Government Obligations in All Member Banks in Cities with 500,000 or More Residents
# Balances with Domestic Banks in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Loans and Investments in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Balances with Domestic Banks in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Reserves with Federal Reserve Banks for All Member Banks in Cities with 500,000 or More Residents
# Deposits in All Member Banks in Cities with 500,000 or More Residents
# Deposits in All Member Banks in Cities with 500,000 or Fewer Residents
# Investments in All Member Banks in Cities with 500,000 or More Residents
# Time Deposits in All Member Banks in Cities with 500,000 or More Residents
# Time Deposits in All Member Banks in Cities with 500,000 or Fewer Residents
# Balances with Domestic Member Banks in Cities with 500,000 or More Residents
# Cash in Vault for All Member Banks in Cities with 500,000 or Fewer Residents
# Demand Deposits in All Member Banks in Cities with 500,000 or More Residents
# Balances with Domestic Member Banks in Cities with 500,000 or Fewer Residents
# Demand Deposits in All Member Banks in Cities with 500,000 or Fewer Residents
# Loans in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Interbank Deposits in All Member Banks in Cities with 500,000 or More Residents
# Investments in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Loans in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Investments in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Cash in Vault for All Insured Commercial Banks in Cities with 500,000 or More Residents
# Other Securities in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Other Securities in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Time Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Cash in Vault for Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Time Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Loans and Investments in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Cash in Vault for Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Loans and Investments in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Demand Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Interbank Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# United States Government Obligations in All Member Banks in Cities with 500,000 or Fewer Residents
# Interbank Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Loans and Investments in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Balances with Domestic Banks in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Balances with Domestic Banks in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Reserves with Federal Reserve Banks for All Insured Commercial Banks in Cities with 500,000 or More Residents
# United States Government Obligations in All Insured Commercial Banks in Cities with 500,000 or More Residents
# Reserves with Federal Reserve Banks for All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# United States Government Obligations in All Insured Commercial Banks in Cities with 500,000 or Fewer Residents
# Loans in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Demand Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Deposits in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Investments in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Investments in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# Other Securities in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# Other Securities in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# United States Government Obligations in Insured Nonmember Commercial Banks in Cities with 500,000 or More Residents
# United States Government Obligations in Insured Nonmember Commercial Banks in Cities with 500,000 or Fewer Residents
# St. Louis Fed Financial Stress Index (DISCONTINUED)
# Median Household Income in California
# National Rate on Non-Jumbo Deposits (less than $100,000): Savings (DISCONTINUED)
# National Rate on Non-Jumbo Deposits (less than $100,000): 12 Month CD (DISCONTINUED)
# Real Median Household Income in New York
# Equity Market Volatility Tracker: Overall
# National Rate on Jumbo Deposits (greater or equal to $100,000): Money Market (DISCONTINUED)
# Real Median Household Income in the District of Columbia
# Real Median Household Income in California
# Real Median Household Income in Massachusetts
# Real Median Household Income in Florida
# National Rate on Non-Jumbo Deposits (less than $100,000): Money Market (DISCONTINUED)
# National Rate on Jumbo Deposits (greater or equal to $100,000): 3 Month CD (DISCONTINUED)
# Brave-Butters-Kelley Real Gross Domestic Product
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Business Investment And Sentiment
# Brave-Butters-Kelley Real Gross Domestic Product
# National Rate on Non-Jumbo Deposits (less than $100,000): Interest Checking (DISCONTINUED)
# Real Median Household Income in Texas
# National Rate on Jumbo Deposits (greater or equal to $100,000): 12 Month CD (DISCONTINUED)
# Median Household Income in Illinois
# Real Median Household Income in Oklahoma
# Real Median Household Income in Arizona
# Real Median Household Income in New Jersey
# Brave-Butters-Kelley Leading Index
# Brave-Butters-Kelley Leading Index
# ICE BofA US Emerging Markets Liquid Corporate Plus Index Total Return Index Value
# Real Median Household Income in Colorado
# Real Median Household Income in Pennsylvania
# Real Median Household Income in Michigan
# National Rate on Jumbo Deposits (greater or equal to $100,000): 60 Month CD (DISCONTINUED)
# Real Median Household Income in Minnesota
# Real Median Household Income in Ohio
# Equity Market Volatility Tracker: Immigration
# Real Median Household Income in Kentucky
# Real Median Household Income in North Carolina
# Real Median Household Income in Missouri
# Real Median Household Income in Utah
# Real Median Household Income in Wisconsin
# Real Median Household Income in West Virginia
# Median Household Income in Idaho
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Interest Rates
# Real Median Household Income in Indiana
# Equity Market Volatility Tracker: Monetary Policy
# Median Household Income in Nevada
# Median Household Income in Alabama
# Median Household Income in Florida
# Median Household Income in Tennessee
# Equity Market Volatility Tracker: Government Spending Deficits And Debt
# Real Median Household Income in Maryland
# Real Median Household Income in Arkansas
# Real Median Household Income in Illinois
# Median Household Income in Georgia
# Median Household Income in Nebraska
# Real Median Household Income in Connecticut
# Real Median Household Income in Alabama
# Equity Market Volatility Tracker: Financial Crises
# Median Household Income in Oregon
# Median Household Income in Louisiana
# Median Household Income in Texas
# Median Household Income in South Carolina
# National Rate on Non-Jumbo Deposits (less than $100,000): 1 Month CD (DISCONTINUED)
# Median Household Income in Maine
# Real Median Household Income in Washington
# Median Household Income in Utah
# Equity Market Volatility Tracker: Elections And Political Governance
# Median Household Income in Colorado
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Inflation
# National Rate on Jumbo Deposits (greater or equal to $100,000): 36 Month CD (DISCONTINUED)
# National Rate on Non-Jumbo Deposits (less than $100,000): 6 Month CD (DISCONTINUED)
# Real Median Household Income in Kansas
# Median Household Income in Montana
# Median Household Income in New Hampshire
# Rate Cap on Non-Jumbo Deposits (less than $100,000): Savings (DISCONTINUED)
# Median Household Income in Massachusetts
# National Rate on Non-Jumbo Deposits (less than $100,000): 60 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Exchange Rates
# Median Household Income in Mississippi
# Median Household Income in Washington
# Real Median Household Income in Alaska
# Median Household Income in West Virginia
# Median Household Income in Missouri
# Real Median Household Income in South Dakota
# Rate Cap on Non-Jumbo Deposits (less than $100,000): Interest Checking (DISCONTINUED)
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Consumer Spending And Sentiment
# Brave-Butters-Kelley Cycle: Lagging Subcomponent of GDP
# Brave-Butters-Kelley Cycle: Lagging Subcomponent of GDP
# Brave-Butters-Kelley Cycle Component of GDP
# Median Household Income in Connecticut
# Real Median Household Income in New Mexico
# Real Median Household Income in Virginia
# Median Household Income in Wisconsin
# National Rate on Non-Jumbo Deposits (less than $100,000): 3 Month CD (DISCONTINUED)
# Real Median Household Income in Mississippi
# National Rate on Jumbo Deposits (greater or equal to $100,000): 6 Month CD (DISCONTINUED)
# National Rate on Jumbo Deposits (greater or equal to $100,000): 1 Month CD (DISCONTINUED)
# Median Household Income in Maryland
# Median Household Income in Hawaii
# Equity Market Volatility Tracker: Energy And Environmental Regulation
# Equity Market Volatility Tracker: Fiscal Policy
# Median Household Income in Oklahoma
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): Money Market (DISCONTINUED)
# New Houses Sold by Sales Price in the United States, Between $150,000 and $199,999
# New Houses Sold by Sales Price in the United States, Between $750,000 and Over
# Brave-Butters-Kelley Trend Component of GDP
# Brave-Butters-Kelley Cycle Component of GDP
# Brave-Butters-Kelley Trend Component of GDP
# Median Household Income in Minnesota
# Real Median Household Income in South Carolina
# Median Household Income in Kentucky
# Median Household Income in New Jersey
# Real Median Household Income in Wyoming
# Real Median Household Income in Oregon
# Real Median Household Income in Louisiana
# Median Household Income in North Dakota
# Real Median Household Income in Hawaii
# Real Median Household Income in New Hampshire
# Brave-Butters-Kelley Coincident Index
# Brave-Butters-Kelley Coincident Index
# Median Household Income in Arizona
# Median Household Income in Delaware
# Equity Market Volatility Tracker: Commodity Markets
# Real Median Household Income in Georgia
# Real Median Household Income in Rhode Island
# Median Household Income in Iowa
# Median Household Income in District of Columbia
# Real Median Household Income in Tennessee
# Real Median Household Income in Maine
# Real Median Household Income in Nevada
# Median Household Income in North Carolina
# Median Household Income in Pennsylvania
# National Rate on Non-Jumbo Deposits (less than $100,000): 48 Month CD (DISCONTINUED)
# Median Household Income in Michigan
# Real Median Household Income in Vermont
# Brave-Butters-Kelley Cycle: Leading Subcomponent of GDP
# Brave-Butters-Kelley Cycle: Leading Subcomponent of GDP
# Median Household Income in Virginia
# Real Median Household Income in Iowa
# Rate Cap on Non-Jumbo Deposits (less than $100,000): Money Market (DISCONTINUED)
# ICE BofA US Emerging Markets Liquid Corporate Plus Index Option-Adjusted Spread
# Real Median Household Income in North Dakota
# Median Household Income in Kansas
# Equity Market Volatility Tracker: Healthcare Matters
# National Rate on Non-Jumbo Deposits (less than $100,000): 36 Month CD (DISCONTINUED)
# Real Median Household Income in Montana
# Median Household Income in Rhode Island
# Brave-Butters-Kelley Irregular Component of GDP
# New Houses Sold by Sales Price in the United States, Between $300,000 and $399,999
# New Houses Sold by Sales Price in the United States, Under $150,000
# Brave-Butters-Kelley Irregular Component of GDP
# ICE BofA US Emerging Markets Liquid Corporate Plus Index Effective Yield
# New Houses Sold by Sales Price in the United States, Between $400,000 and $499,999
# Median Household Income in New York
# National Rate on Non-Jumbo Deposits (less than $100,000): 24 Month CD (DISCONTINUED)
# Real Median Household Income in Nebraska
# Equity Market Volatility Tracker: Healthcare Policy
# Median Household Income in Wyoming
# Real Median Household Income in Delaware
# Real Median Household Income in Idaho
# National Rate on Jumbo Deposits (greater or equal to $100,000): 48 Month CD (DISCONTINUED)
# National Rate on Jumbo Deposits (greater or equal to $100,000): 24 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Other Financial Indicators
# New Houses Sold by Sales Price in the United States, Between $200,000 and $299,999
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Trade
# Median Household Income in New Mexico
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 12 Month CD (DISCONTINUED)
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 60 Month CD (DISCONTINUED)
# Median Household Income in Ohio
# Equity Market Volatility Tracker: Housing And Land Management
# ICE BofA US Emerging Markets Liquid Corporate Plus Index Semi-Annual Yield to Worst
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Real Estate Markets
# Equity Market Volatility Tracker: Trade Policy
# Equity Market Volatility Tracker: Financial Regulation
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 60 Month CD (DISCONTINUED)
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 1 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Transportation, Infrastructure, and Public Utilities
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 12 Month CD (DISCONTINUED)
# Median Household Income in Alaska
# Equity Market Volatility Tracker: Taxes
# Contributions to the Cleveland Financial Stress Index: Stock Market Crashes (DISCONTINUED)
# Equity Market Volatility Tracker: Macroeconomic News And Outlook
# Equity Market Volatility Tracker: Policy Related
# Equity Market Volatility Tracker: Lawsuit And Tort Reform Supreme Court Decisions
# Equity Market Volatility Tracker: Entitlement And Welfare Programs
# Median Household Income in Indiana
# Bills Bought, Federal Reserve Banks for United States
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 3 Month CD (DISCONTINUED)
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 24 Month CD (DISCONTINUED)
# Contracts for Construction Other Than Buildings for United States
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 48 Month CD (DISCONTINUED)
# Amplitude Adjusted Composite Index of Leading Series, Six Series, Unweighted for United States
# Median Household Income in South Dakota
# Median Household Income in Vermont
# Median Household Income in Arkansas
# Freight Car Shipments, Domestic for United States
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Labor Markets
# Banana Imports for United States
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 48 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Macroeconomic News and Outlook: Broad Quantity Indicators
# Foreign Official Assets in the U.S.: Net (DISCONTINUED)
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 6 Month CD (DISCONTINUED)
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 3 Month CD (DISCONTINUED)
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 1 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Regulation
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 36 Month CD (DISCONTINUED)
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 6 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Litigation Matters
# Rate Cap on Jumbo Deposits (greater or equal to $100,000): 36 Month CD (DISCONTINUED)
# Rate Cap on Non-Jumbo Deposits (less than $100,000): 24 Month CD (DISCONTINUED)
# Equity Market Volatility Tracker: Competition Matters
# Equity Market Volatility Tracker: Agricultural Policy
# Equity Market Volatility Tracker: Intellectual Property Policy
# Equity Market Volatility Tracker: Labor Regulations
# Equity Market Volatility Tracker: Food And Drug Policy
# Equity Market Volatility Tracker: Labor Disputes
# Equity Market Volatility Tracker: Competition Policy
# Equity Market Volatility Tracker: Intellectual Property Matters
# Equity Market Volatility Tracker: National Security Policy
# Equity Market Volatility Tracker: Government Sponsored Enterprises
# Wool, Wholesale Price for Berlin, Germany
# New Houses Sold by Sales Price, Total, in Midwest Census Region
# Total building Contracts, Engineering News-Record for United States
# Equity Market Volatility Tracker: Other Regulation
# New Houses Sold by Sales Price, Total, in Northeast Census Region
# New Corporate Securities Offered for Cash, Proposed Use of Estimated Net Proceeds Other Than New Money and Retirement of Securities for United States
# Contracts for Industrial Buildings, Value, Engineering News-Record for United States
# New Houses Sold by Sales Price Between $750,000 and Over in Northeast Census Region
# New Houses Sold by Sales Price, Total, in West Census Region
# New Houses Sold by Sales Price, Under $200,000 in Northeast Census Region
# New Houses Sold by Sales Price, Total, in South Census Region
# New Houses Sold by Sales Price Between $300,000 and $499,999 in South Census Region
# New Houses Sold by Sales Price Between $200,000 and $299,999 in West Census Region
# New Houses Sold by Sales Price Between $200,000 and $299,999 in Northeast Census Region
# New Houses Sold by Sales Price Between $300,000 and $499,999 in Northeast Census Region
# New Securities Offered for Cash, Estimated Gross Proceeds, Public Utility Industry, Total Securities for United States
# New Houses Sold by Sales Price Between $300,000 and $499,999 in Midwest Census Region
# New Houses Sold by Sales Price Between $200,000 and $299,999 in Midwest Census Region
# New Houses Sold by Sales Price, Under $150,000 in Midwest Census Region
# New Houses Sold by Sales Price, Under $200,000 in West Census Region
# New Houses Sold by Sales Price Between $150,000 and $199,999 in South Census Region
# New Houses Sold by Sales Price Between $300,000 and $499,999 in West Census Region
# New Houses Sold by Sales Price Between $750,000 and Over in West Census Region
# New Houses Sold by Sales Price Between $150,000 and $199,999 in Midwest Census Region
# New Houses Sold by Sales Price Between $200,000 and $299,999 in South Census Region
# New Houses Sold by Sales Price, Under $150,000 in South Census Region

# %%
#https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=YOUR_API_KEY
